# %%
import pandas as pd

df = pd.read_csv("dataset/avocado.csv")
df['Date'] = pd.to_datetime(df["Date"])
boston_df = df[df["region"]=="Boston"]
boston_df.set_index("Date", inplace=True)
boston_df.sort_index(inplace=True)
boston_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# C:\Users\joshf\AppData\Local\Temp\ipykernel_38284\74989374.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston_df.sort_index(inplace=True)
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

df = pd.read_csv("dataset/avocado.csv")
df['Date'] = pd.to_datetime(df["Date"])
us_df = df
us_df.set_index("Date", inplace=True)
us_df.sort_index(inplace=True)
us_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

df = pd.read_csv("dataset/avocado.csv")
us_df = df
us_df.set_index("Total Volume", inplace=False)
us_df.sort_index(inplace=False)
us_df["AveragePrice"].rolling(50).mean().plot()
# Out:
# <AxesSubplot:>
